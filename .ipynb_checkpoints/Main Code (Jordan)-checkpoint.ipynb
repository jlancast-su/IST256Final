# %%
#PROCESS:
#3 Methods
#   Location (Based off ZIP)
#      Picking store (Store Rating, Hours, Address)
#   Give choices for Product (In Catergories) [???]
#      List: Avaliblity (quantity), Price, Warrenty, Pre-owned, Description
#           (Add additional method for addtional information)
#   Conclusion (List of prodcuts choosen, Store hours & Address)
BB_url_products= 'https://api.bestbuy.com/v1/products?apiKey=PO1GPj1c2yOdKQLEdYMfG6P9'
BB_url_stores = 'https://api.bestbuy.com/v1/stores?apiKey=PO1GPj1c2yOdKQLEdYMfG6P9'
BB_url_stores = 'https://api.bestbuy.com/v1/categories?apiKey=PO1GPj1c2yOdKQLEdYMfG6P9'

# %%
#Systems, Formats, Packages
# !pip install -q requests
# !pip install chart-studio
import urllib, base64
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import requests
import json

# %%
response = requests.get(BB_url)
response.ok
# Out:
# False

# %%
# STEP 1: Shopping list

#Creates shopping list for user
#Holds Product's name, price, and quanitity
#!!!!!EDIT: displaying list and checking in the list
def Shopping_List():
    shoppinglist =[]
    total = 0
    while True:
        item = {}
        print("\nEnter proper information or type 'stop'.")

        item["Product Name:"] = input("What is the name of the product? ")
        if(item["Product Name:"] == 'stop'):
            break
        item["Price:"] = float(input("What is the price of the product? "))
        item["Quantity:"] = int(input("How many will you be buying? "))

        shoppinglist.append(item)
    print("")
    for item in shoppinglist:
        total += (item["Price:"] * item["Quantity:"])
        print("Product: %s, Price: $%.2f, Quantity: %d" %(item["Product Name:"], item["Price:"], item['Quantity:']))
    print("Your total is $%.2f" %total)
    return shoppinglist


# Incorporate this code into the one above
# (Might need to make other methods to work smoothly)
#def print_menu():
#    print("A - Add Item to Shopping List")
#    print("P - Print Shopping List")
#    print("R - Remove Item from Shopping List")
#    print("Q - Quit Shopping List Program")
#    print("")
#    return

#def add_item(shopping_list):
    #todo write code here
#    print("What are you adding to your shopping list?")
#  print("Press 'q' to stop")
#    while True:
      
#        new_add = input().lower()
#       if new_add == 'q':
#            break
#        elif new_add in shopping_list:
#            print("already in the shopping list")
#            continue
            
#       shopping_list.append(new_add)
#    return shopping_list

#def print_list(shopping_list):
    #todo write code here
    #count = 0
    #print("\nSHOPPPING LIST: ")
    #for i in shopping_list:
        #count +=1
        #print(f"{count}. {i}")
    
   #print("")
    #return shopping_list


#def remove_item(shopping_list):
    #count = 0
    #prompt, print list, input
    #print("what item do you wish to delete")
    #for i in shopping_list:
        #count +=1
        #print(f"{count}. {i}")
    #choice = input()
#reset count

    #count = 0
    #num=0

#have the user delete item by number
    #if choice.isdigit():
        #choice = int(choice)-1
        #if choice in range(0, len(shopping_list)):
            #del shopping_list[choice]
            #print(f"Deleting {choice+1} for you...")

            
#have user delete item by name
    #elif choice.isdigit() == False:
        #for i in shopping_list:
            #num = i.find(choice)
        #shopping_list.remove(choice)
        
        #print(f"Deleting {choice} for you...")
    #return shopping_list        


## Main Program Written For You
#shopping_list = []
#print_menu()
#while True:
    #choice = input("Enter choice (A, P, R, Q): ").upper()
    #if choice == 'A':
        #shopping_list = add_item(shopping_list)
    #elif choice == 'P':
        #shopping_list = print_list(shopping_list)
    #elif choice == 'R':
        #shopping_list = remove_item(shopping_list)
    #elif choice == "Q":
        #break
    #else:
        #print('ERROR:', choice,'is not a menu option')
#print("\nDon't forget these when you go to the store next time!")
#for i in shopping_list:
    #print(i)

# %%
#Step 2: Location

#Here is the format in which data will be returned from Wegman's API
# Using the Map API (Openstreets or Wegman) find the store number and use that to reference the store we look
# into for product inventory.
Weg_store_info = {
  "number": 1,
  "name": "JOHN GLENN",
  "type": "Wegmans Store",
  "hasPharmacy": True,
  "salesTaxPercentage": 0.08,
  "totalSquareFootage": 113991,
  "address": {
    "street": "7519 Oswego Road",
    "city": "Liverpool",
    "county": "ONONDAGA",
    "state": {
      "name": "NEW YORK",
      "abbreviation": "NY"
    },
    "zip": "13090",
    "latitude": 43.13316,
    "longitude": -76.2232
  },
  "_links": [
    {
      "href": "/stores?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "stores",
      "type": "GET"
    }
  ]
}


#Get the price and add to sum total
#(Will also need tax percentage in the area)
Weg_price_info = {
  "price": 0.0,
  "quantity": 0,
  "dates": {
    "start": "string",
    "end": "string"
  },
  "promotion": {
    "price": 0.0,
    "quantity": 0,
    "dates": {
      "start": "string",
      "end": "string"
    }
  },
  "_links": [
    {
      "href": "string",
      "rel": "string",
      "type": "string"
    }
  ]
}

# %%
#STEP 3: Total, Subtotal, Nutrition facts, 
Weg_prod_info = {
    "value": 1,
    "unitOfMeasure": "LB"
  },
  "status": "Store Active",
      "wellnessKeys": [],
      "countryOfOrigin": null,
      "disclaimer": null,
      "isRaw": false,
      "isMsgFree": false,
      "isAntibioticFree": false,
      "isCornFree": false,
      "isLactoovoVegetarian": false,
      "isFairtrade": false,
      "isIrradiated": false,
      "isCertifiedHumane": false,
      "isWildCaught": false,
      "hasNoAddedHormones": false,
      "geneticallyModifiedDeclaration": null,
      "averageSellableWeight": 1.06,
      "alcohol": {
        "type": null,
        "volume": 0,
        "style": null,
        "varietal": null,
        "maker": null,
        "foodPairings": []
      },
      "diets": [],
      "additives": [],
      "allergens": [],
      "ingredients": [],
      "nutrients": [
    {
      "type": "Cholesterol",
      "quantity": "70 mg",
      "precision": null,
      "dailyValuePercent": 0.23,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Potassium",
      "quantity": "260 mg",
      "precision": null,
      "dailyValuePercent": 0.07,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Protein",
      "quantity": "20 g",
      "precision": null,
      "dailyValuePercent": 0,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Saturated Fat",
      "quantity": "6 g",
      "precision": null,
      "dailyValuePercent": 0.32,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Sodium",
      "quantity": "90 mg",
      "precision": null,
      "dailyValuePercent": 0.04,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Total Carbohydrate",
      "quantity": "0 g",
      "precision": null,
      "dailyValuePercent": 0,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    },
    {
      "type": "Total Fat",
      "quantity": "14 g",
      "precision": null,
      "dailyValuePercent": 0.22,
      "dailyValueReference": null,
      "itemQuantity": {
        "value": 1,
        "unitOfMeasure": "LB"
      }
    }
  ],
  "nutrition": [],
  "organic": {
    "agency": null,
    "percent": 0
  },
  "preparation": {
    "instructions": null,
    "state": null
  },
  "servings": {
    "suggestion": null,
    "perPackage": 0
  },
  "tradeIdentifiers": [
    {
      "images": [
        {
          "url": "https://wegmans.com/content/dam/wegmans/products/914/11914.jpg"
        }
      ],
      "barcodes": [
        {
          "barcode": "20165900000",
          "_links": [
            {
              "href": "/products/barcodes/20165900000?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
              "rel": "self",
              "type": "GET"
            }
          ]
        }
      ],
      "height": {
        "value": 6,
        "unitOfMeasure": "IN"
      },
      "width": {
        "value": 8,
        "unitOfMeasure": "IN"
      },
      "weight": {
        "value": 0,
        "unitOfMeasure": null
      }
    }
  ],
  "states": [
    {
      "state": "MA",
      "tax": {
        "type": 0,
        "description": "No Tax"
      },
      "hasDeposit": false
    },
    {
      "state": "MD",
      "tax": {
        "type": 0,
        "description": "No Tax"
      },
      "hasDeposit": false
    },
    {
      "state": "NJ",
      "tax": {
        "type": 0,
        "description": "No Tax"
      },
      "hasDeposit": false
    },
    {
      "state": "NY",
      "tax": {
        "type": 0,
        "description": "No Tax"
      },
      "hasDeposit": false
    },
    {
      "state": "PA",
      "tax": {
        "type": 0,
        "description": "No Tax"
      },
      "hasDeposit": false
    },
    {
      "state": "VA",
      "tax": {
        "type": 3294,
        "description": "Low"
      },
      "hasDeposit": false
    }
  ],
  "_links": [
    {
      "href": "/products/11914?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "self",
      "type": "GET"
    },
    {
      "href": "/products/11914/locations?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "locations",
      "type": "GET"
    },
    {
      "href": "/products/11914/availabilities?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "availabilities",
      "type": "GET"
    },
    {
      "href": "/products/11914/prices?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "prices",
      "type": "GET"
    },
    {
      "href": "/products/categories/715-722?api-version=2018-10-18&subscription-key=0123456789abcdef0123456789abcdef",
      "rel": "category",
      "type": "GET"
    },
    {
      "href": "/products/categories/715-844?api-version=2018-10-18&subscription-key="+ subscription_key,
      "rel": "category",
      "type": "GET"
    }
  ]
}
