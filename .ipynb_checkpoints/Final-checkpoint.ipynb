# %%
#Imports, Systems, and Packages
# !pip install -q requests
# !pip install chart-studio
import urllib, base64
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import requests
import json
# Out:
# Requirement already satisfied: chart-studio in /opt/conda/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from chart-studio) (2.22.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from chart-studio) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from chart-studio) (1.3.3)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from chart-studio) (4.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->chart-studio) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->chart-studio) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->chart-studio) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->chart-studio) (2019.6.16)

# %%
print("Hello, Welcome to the Best Buy SmartSearch!")
url = input("Please enter 'Stores' or 'Products': ").lower()
    
if url == 'stores':
    user_input = int(input('Enter your zipcode: '))
    area_url = "https://api.bestbuy.com/v1/stores(area(%s,50))?format=json&show=storeId,storeType,hours,phone,address,name&pageSize=5&apiKey=PO1GPj1c2yOdKQLEdYMfG6P9" % (user_input)
    response = requests.get(area_url)
    data = response.json()
    print('')
    try:
        for i in range(0,len(data)):
            print("STORE NAME: "+ data['stores'][i]['name'])
            print("STORE HOURS: " + data['stores'][i]['hours'])
            print("STORE PHONE NUMBER: " + data['stores'][i]['phone'])
            print("STORE ADDRESS: "+ data['stores'][i]['address'])
            i+=1
            
            print('')
            print('')
            
    except IndexError:
        print('...')

tote =0        
prod_sl = []
while True:
    prods = {}
    user_input1 = (input("Enter a product you want to purchase: ('q' to quit)"))
    if(user_input1 == 'q'):
        break
    user_in1_ls = user_input1.split()
    user_input1 = ''

    for i in range(0, len(user_in1_ls)):
        if(i+2 > len(user_in1_ls)):
            user_input1 += "search="+user_in1_ls[i]
        else:
            user_input1 += "search="+user_in1_ls[i]+'&'



    product_url = f"https://api.bestbuy.com/v1/products(%s)?format=json&show=sku,name,preowned,digital,salePrice&apiKey=PO1GPj1c2yOdKQLEdYMfG6P9" % (user_input1)
    response = requests.get(product_url)
    product_data = response.json()
    try:
        for i in range(0,len(product_data)):
            print(i, ')')
            print("PRODUCTS NAME: "+ product_data['products'][i]['name'])
            print("PRODUCTS PRICE: ", product_data['products'][i]['salePrice'])
            print("PRODUCTS PREOWNED: ", product_data['products'][i]['preowned'])
            i+=1

            print('')
            print('')
    except IndexError:
            print('...')

    while True: 

        user_prod_picked = int(input("Would you like to add any items to your Smart Search? (-1 to quit)"))

        if(user_prod_picked == -1):
            print('...')
            break


        if i not in range(0,len(product_data)):
            prods['name'] = product_data['products'][user_prod_picked]['name']
            prods['price'] = product_data['products'][user_prod_picked]['salePrice']
            prods['preowned'] = product_data['products'][user_prod_picked]['preowned']
            tote+=prods['price']
            prods['Total'] = tote

            prod_sl.append(prods)
            print(f"%.2f"%(tote))
        else:
            print("not adding to the cart...")

print("")
print("Thank you for using our Program!")

count = 0
for i in range(0,len(prod_sl)):
    print(i+1, ')')
    print("PRODUCTS NAME: " + prod_sl[i]['name'])
    print("PRODUCTS PRICE: ", prod_sl[i]['price'])
    i+=1
    count =i
    print('')


print(f"Your total is $%.2f" %(prod_sl[len(prod_sl)-1]['Total']))
# Out:
# Hello, Welcome to the Best Buy SmartSearch!
# Please enter 'Stores' or 'Products': stores
# Enter your zipcode: 13244
#
# STORE NAME: SYRACUSE NY
# STORE HOURS: Sun: 11-6; Mon: 10-10; Tue: 10-10; Wed: 10-10; Thurs: 10-10; Fri: 10-10; Sat: 10-10; Sun: 9-10; Mon: 9-10; Tue: 9-10; Wed: 9-10; Thurs: 9-10; Fri: 8-11; Sat: 8-11
# STORE PHONE NUMBER: 315-426-1588
# STORE ADDRESS: 9090 Destiny USA Dr
#
#
# STORE NAME: DEWITT NY
# STORE HOURS: Sun: 10-8; Mon: 10-10; Tue: 10-10; Wed: 10-10; Thurs: 10-10; Fri: 9-11; Sat: 9-11; Sun: 10-8; Mon: 8-11; Tue: 8-11; Wed: 8-11; Thurs: 8-11; Fri: 8-11; Sat: 8-11
# STORE PHONE NUMBER: 315-449-1784
# STORE ADDRESS: 3401 Erie Blvd E
#
#
# STORE NAME: NEW HARTFORD NY
# STORE HOURS: Sun: 10-8; Mon: 10-10; Tue: 10-10; Wed: 10-10; Thurs: 10-10; Fri: 9-11; Sat: 9-11; Sun: 10-8; Mon: 8-11; Tue: 8-11; Wed: 8-11; Thurs: 8-11; Fri: 8-11; Sat: 8-11
# STORE PHONE NUMBER: 315-736-8710
# STORE ADDRESS: 4725 Commercial Dr
#
#
# STORE NAME: ITHACA NY
# STORE HOURS: Sun: 10-8; Mon: 10-10; Tue: 10-10; Wed: 10-10; Thurs: 10-10; Fri: 9-11; Sat: 9-11; Sun: 10-8; Mon: 8-11; Tue: 8-11; Wed: 8-11; Thurs: 8-11; Fri: 8-11; Sat: 8-11
# STORE PHONE NUMBER: 607-257-6824
# STORE ADDRESS: 40 Catherwood Rd
#
#
# ...
# Enter a product you want to purchase: ('q' to quit)iphone case
# 0 )
# PRODUCTS NAME: ROQQ Case - Blossom Series Case for Apple® iPhone® XR - Yellow Cosmos & Hydrangeas
# PRODUCTS PRICE:  34.99
# PRODUCTS PREOWNED:  False
#
#
# 1 )
# PRODUCTS NAME: ROQQ Case - Blossom Series Case for Apple® iPhone® X and XS - Yellow Cosmos & Hydrangeas
# PRODUCTS PRICE:  34.99
# PRODUCTS PREOWNED:  False
#
#
# 2 )
# PRODUCTS NAME: ROQQ Case - Blossom Series Case for Apple® iPhone® XS Max - Yellow Cosmos & Hydrangeas
# PRODUCTS PRICE:  34.99
# PRODUCTS PREOWNED:  False
#
#
# 3 )
# PRODUCTS NAME: Element Case - REV Case for Apple® iPhone® 7 and 8 - Red
# PRODUCTS PRICE:  25.99
# PRODUCTS PREOWNED:  False
#
#
# 4 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Elite Case for Apple iPhone XS Max - Black
# PRODUCTS PRICE:  249.99
# PRODUCTS PREOWNED:  False
#
#
# 5 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Case for Apple iPhone XS Max - Black
# PRODUCTS PRICE:  199.99
# PRODUCTS PREOWNED:  False
#
#
# 6 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Elite Case for Apple iPhone XR - Black
# PRODUCTS PRICE:  249.99
# PRODUCTS PREOWNED:  False
#
#
# 7 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Elite Case for Apple iPhone X and XS - Black
# PRODUCTS PRICE:  249.99
# PRODUCTS PREOWNED:  False
#
#
# 8 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Case for Apple iPhone XR - Black
# PRODUCTS PRICE:  199.99
# PRODUCTS PREOWNED:  False
#
#
# 9 )
# PRODUCTS NAME: Element Case - Black OPS Case for Apple® iPhone® X and XS - Black
# PRODUCTS PRICE:  199.99
# PRODUCTS PREOWNED:  False
#
#
# Would you like to add any items to your Smart Search? (-1 to quit)8
# 199.99
# Would you like to add any items to your Smart Search? (-1 to quit)-1
# ...
# Enter a product you want to purchase: ('q' to quit)laptop
# 0 )
# PRODUCTS NAME: Speck - Rucker Backpack for 15" Laptops - Charcoal
# PRODUCTS PRICE:  59.95
# PRODUCTS PREOWNED:  False
#
#
# 1 )
# PRODUCTS NAME: PKG - Laptop Sleeve - Dark gray
# PRODUCTS PRICE:  49.99
# PRODUCTS PREOWNED:  False
#
#
# 2 )
# PRODUCTS NAME: PKG - Sleeve for 14" Laptop - Black
# PRODUCTS PRICE:  50.0
# PRODUCTS PREOWNED:  False
#
#
# 3 )
# PRODUCTS NAME: Case Logic - Laptop Sleeve - Pink
# PRODUCTS PRICE:  18.99
# PRODUCTS PREOWNED:  False
#
#
# 4 )
# PRODUCTS NAME: Case Logic - Laptop Sleeve - Black
# PRODUCTS PRICE:  16.99
# PRODUCTS PREOWNED:  False
#
#
# 5 )
# PRODUCTS NAME: Case Logic - Laptop Sleeve - Black
# PRODUCTS PRICE:  22.99
# PRODUCTS PREOWNED:  False
#
#
# 6 )
# PRODUCTS NAME: PKG - Laptop Sleeve - Gray
# PRODUCTS PRICE:  59.99
# PRODUCTS PREOWNED:  False
#
#
# 7 )
# PRODUCTS NAME: Samsonite - Laptop Backpack - Black
# PRODUCTS PRICE:  94.99
# PRODUCTS PREOWNED:  False
#
#
# 8 )
# PRODUCTS NAME: Targus - Sleeve for 14" Laptop - Black
# PRODUCTS PRICE:  16.99
# PRODUCTS PREOWNED:  False
#
#
# 9 )
# PRODUCTS NAME: PKG - Sleeve for 13" Laptop - Lilac
# PRODUCTS PRICE:  44.99
# PRODUCTS PREOWNED:  False
#
#
# Would you like to add any items to your Smart Search? (-1 to quit)3
# 218.98
# Would you like to add any items to your Smart Search? (-1 to quit)-1
# ...
# Enter a product you want to purchase: ('q' to quit)q
#
# Thank you for using our Program!
# 1 )
# PRODUCTS NAME: Element Case - Black OPS 2018 Case for Apple iPhone XR - Black
# PRODUCTS PRICE:  199.99
#
# 2 )
# PRODUCTS NAME: Case Logic - Laptop Sleeve - Pink
# PRODUCTS PRICE:  18.99
#
# Your total is $218.98

# %% [markdown]
# #
